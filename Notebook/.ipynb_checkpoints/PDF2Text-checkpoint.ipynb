# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files (x86)/Tesseract-OCR/tesseract.exe'

# %%
import os  
# Importing the pytesseract module to extract text from images
import pytesseract as tess  
# Importing the Image module from the PIL package to work with images
from PIL import Image  
# Importing the convert_from_path function from the pdf2image module to convert PDF files to images
from pdf2image import convert_from_path  

def read_scanned_pdf(file_address,file_name):
    '''This function takes a PDF file name as input and returns the name of the text file that contains the extracted text.'''
    # Store all pages of one file here:
    pages = []

    try:
        # Convert the PDF file to a list of PIL images:
        images = convert_from_path(file_address)  

        # Extract text from each image:
        for i, image in enumerate(images):
          # Generating filename for each image
            filename =  os.path.splitext(file_address)[0] + "_" +"page_" + str(i) + ".jpeg"  
            image.save(filename, "JPEG")  
          # Saving each image as JPEG
            text = tess.image_to_string(Image.open(filename))  # Extracting text from each image using pytesseract
            pages.append(text)  
          # Appending extracted text to pages list
            os.remove(filename)
          # Delete the generated image file

    except Exception as e:
        print(str(e))

    # Write the extracted text to a file:
    output_file_name = "C:/Users/sakhi/Desktop/NLP/results"+"/"+os.path.splitext(file_name)[0] + ".txt"  # Generating output file name
    with open(output_file_name, "w", encoding="utf-8") as f:
        f.write("\n".join(pages))  
      # Writing extracted text to output file

    return output_file_name

#print function returns the final converted text 
#print(read_pdf(pdf_file))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
#       2 # Importing the pytesseract module to extract text from images
# ----> 3 import pytesseract as tess
#       4 # Importing the Image module from the PIL package to work with images
#       5 from PIL import Image
#
# ModuleNotFoundError: No module named 'pytesseract'

# %%
import fitz
# a module in PyMuPDF

def is_text_based(doc):
    for page in doc:
        # Extract text from the page
        text = page.get_text()
        # If there's any text content, it's likely text-based
        if text.strip():
            return True
    return False

def read_generated_pdf(doc,file_name):
    text = ""
    for page in doc:
        text += page.get_text()
    
    output_file_name = "C:/Users/sakhi/Desktop/NLP/results"+"/"+os.path.splitext(file_name)[0] + ".txt"
    # Write text content to a text file
    with open(output_file_name, "w", encoding="utf-8") as f:
        f.write(text)
    return output_file_name
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import fitz
#       2 # a module in PyMuPDF
#       4 def is_text_based(doc):
#
# ModuleNotFoundError: No module named 'fitz'

# %%
import fitz
def get_text(file_array,folder_path):
    for pdf_file in file_array:
        address=folder_path+"/"+pdf_file
        with fitz.open(address) as doc:
            if is_text_based(doc):
                print(read_generated_pdf(doc,pdf_file))
            else:
                print(read_scanned_pdf(address,pdf_file))

# %%
from PIL import Image

# %%
import numpy as np
# Define the folder path
folder_path = "C:/Users/sakhi/Desktop/NLP/Files"
# Get all file names in the folder
files = os.listdir(folder_path)

# Convert the list of file names to a NumPy array
file_array = np.array(files)

# Print the file array
print(file_array)
get_text(file_array,folder_path)
# Out:
# ['judgement2022-02-14.pdf' 'judgement2022-02-16.pdf'
#  'judgement2022-02-17.pdf' 'judgement2022-02-23.pdf'
#  'judgement2022-02-28.pdf' 'judgement2022-03-21-01.pdf'
#  'judgement2022-03-22.pdf' 'judgement2022-03-23.pdf'
#  'judgement2022-03-29.pdf' 'judgement2022-03-30.pdf'
#  'judgement2022-03-31.pdf' 'judgement2022-04-01.pdf'
#  'judgement2022-04-13.pdf' 'judgement2022-04-29.pdf'
#  'judgement2022-05-06.pdf' 'judgement2022-05-13.pdf'
#  'judgement2022-05-24.pdf' 'judgement2022-05-27.pdf'
#  'judgement2022-06-02.pdf' 'judgement2022-06-28.pdf'
#  'judgement2022-06-29.pdf' 'judgement2022-06-30.pdf'
#  'judgement2022-07-06.pdf' 'judgement2022-07-15 (2).pdf'
#  'judgement2022-07-15.pdf' 'judgement2022-07-27.pdf'
#  'judgement2022-08-02.pdf' 'judgement2022-08-04-1.pdf'
#  'judgement2022-08-08.pdf' 'judgement2022-08-25.pdf'
#  'judgement2022-09-01.pdf' 'judgement2022-09-30-1.pdf'
#  'judgement2022-09-30.pdf' 'judgement2022-10-28.pdf'
#  'judgement2022-11-01.pdf' 'judgement2022-11-09.pdf'
#  'judgement2022-11-19.pdf' 'judgement2022-12-01.pdf'
#  'judgement2022-12-15.pdf' 'judgement2022-12-20.pdf'
#  'judgement2022-12-23.pdf' 'judgement2022-12-24-N.pdf'
#  'judgement2022-12-28.pdf' 'judgement2023-01-05.pdf'
#  'judgement2023-01-11.pdf' 'judgement2023-01-18.pdf'
#  'judgement2023-02-08.pdf' 'judgement2023-02-09.pdf'
#  'judgement2023-02-20.pdf' 'judgement2023-02-29.pdf'
#  'judgement2023-03-12.pdf' 'judgement2023-03-20-1.pdf'
#  'judgement2023-03-20-2.pdf' 'judgement2023-03-20-3.pdf'
#  'judgement2023-03-20.pdf' 'judgement2023-03-21 (2).pdf'
#  'judgement2023-03-21 (3).pdf' 'judgement2023-03-21-01.pdf'
#  'judgement2023-03-21-1.pdf' 'judgement2023-03-21.pdf'
#  'judgement2023-03-22.pdf' 'judgement2023-03-23.pdf'
#  'judgement2023-03-24 (2).pdf' 'judgement2023-03-24 (3).pdf'
#  'judgement2023-03-24 (4).pdf' 'judgement2023-03-24-01.pdf'
#  'judgement2023-03-24-1.pdf' 'judgement2023-03-24.pdf'
#  'judgement2023-03-27 (2).pdf' 'judgement2023-03-27-01.pdf'
#  'judgement2023-03-27.pdf' 'judgement2023-03-28-2.pdf'
#  'judgement2023-03-29.pdf' 'judgement2023-04-03-01.pdf'
#  'judgement2023-04-03-1.pdf' 'judgement2023-04-03.pdf'
#  'judgement2023-04-11.pdf' 'judgement2023-04-12.pdf'
#  'judgement2023-04-15.pdf' 'judgement2023-04-20.pdf'
#  'judgement2023-04-21-1.pdf' 'judgement2023-04-21.pdf'
#  'judgement2023-04-24 (2).pdf' 'judgement2023-04-24.pdf'
#  'judgement2023-04-26.pdf' 'judgement2023-04-27.pdf'
#  'judgement2023-04-28 (2).pdf' 'judgement2023-04-28.pdf'
#  'judgement2023-04-29.pdf' 'judgement2023-05-10.pdf'
#  'judgement2023-05-11-01.pdf' 'judgement2023-05-11.pdf'
#  'judgement2023-05-12.pdf' 'judgement2023-05-15.pdf'
#  'judgement2023-05-16.pdf' 'judgement2023-05-23.pdf'
#  'judgement2023-05-29-01.pdf' 'judgement2023-05-29.pdf'
#  'judgement2023-05-31.pdf' 'judgement2023-06-01 (2).pdf'
#  'judgement2023-06-01-01.pdf' 'judgement2023-06-01.pdf'
#  'judgement2023-06-05 (2).pdf' 'judgement2023-06-05-1.pdf'
#  'judgement2023-06-05.pdf' 'judgement2023-06-07.pdf'
#  'judgement2023-06-09.pdf' 'judgement2023-06-12 (2).pdf'
#  'judgement2023-06-12-1.pdf' 'judgement2023-06-12.pdf'
#  'judgement2023-06-13.pdf' 'judgement2023-06-14.pdf'
#  'judgement2023-06-20.pdf' 'judgement2023-06-21.pdf'
#  'judgement2023-07-03.pdf' 'judgement2023-07-04 (2).pdf'
#  'judgement2023-07-04-01.pdf' 'judgement2023-07-04.pdf'
#  'judgement2023-07-07.pdf' 'judgement2023-07-26.pdf'
#  'judgement2023-07-31.pdf' 'judgement2023-08-03.pdf'
#  'judgement2023-08-12.pdf' 'judgement2023-08-14.pdf'
#  'judgement2023-08-16.pdf' 'judgement2023-08-31.pdf'
#  'judgement2023-09-04.pdf' 'judgement2023-09-07.pdf'
#  'judgement2023-09-11.pdf' 'judgement2023-09-12.pdf'
#  'judgement2023-09-13.pdf' 'judgement2023-09-15.pdf'
#  'judgement2023-09-18.pdf' 'judgement2023-09-25.pdf'
#  'judgement2023-09-29.pdf' 'judgement2023-10-03.pdf'
#  'judgement2023-10-05.pdf' 'judgement2023-11-03.pdf'
#  'judgement2023-11-08.pdf' 'judgement2023-11-16.pdf'
#  'judgement2023-12-21.pdf' 'judgement2023-12-29.pdf'
#  'judgement2024-01-02-01.pdf' 'judgement2024-01-08.pdf'
#  'judgement2024-01-23 (2).pdf' 'judgement2024-01-23.pdf'
#  'judgement2024-01-24.pdf' 'judgement2024-01-25.pdf'
#  'judgement2024-02-05.pdf' 'judgement2024-02-07.pdf'
#  'judgement2024-03-11 (2).pdf' 'judgement2024-03-13.pdf']
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-02-14.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-02-16.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-02-17.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-02-23.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-02-28.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-03-21-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-03-22.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-03-23.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-03-29.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-03-30.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-03-31.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-04-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-04-13.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-04-29.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-05-06.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-05-13.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-05-24.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-05-27.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-06-02.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-06-28.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-06-29.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-06-30.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-07-06.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-07-15 (2).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-07-15.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-07-27.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-08-02.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-08-04-1.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-08-08.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-08-25.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-09-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-09-30-1.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-09-30.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-10-28.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-11-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-11-09.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-11-19.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-12-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-12-15.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-12-20.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-12-23.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-12-24-N.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2022-12-28.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-01-05.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-01-11.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-01-18.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-02-08.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-02-09.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-02-20.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-02-29.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-12.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-20-1.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-20-2.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-20-3.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-20.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-21 (2).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-21 (3).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-21-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-21-1.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-21.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-22.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-23.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-24 (2).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-24 (3).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-24 (4).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-24-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-24-1.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-24.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-27 (2).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-27-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-27.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-28-2.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-03-29.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-03-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-03-1.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-03.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-11.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-12.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-15.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-20.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-21-1.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-21.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-24 (2).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-24.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-26.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-27.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-28 (2).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-28.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-04-29.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-05-10.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-05-11-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-05-11.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-05-12.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-05-15.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-05-16.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-05-23.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-05-29-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-05-29.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-05-31.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-01 (2).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-01-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-05 (2).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-05-1.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-05.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-07.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-09.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-12 (2).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-12-1.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-12.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-13.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-14.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-20.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-06-21.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-07-03.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-07-04 (2).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-07-04-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-07-04.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-07-07.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-07-26.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-07-31.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-08-03.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-08-12.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-08-14.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-08-16.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-08-31.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-09-04.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-09-07.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-09-11.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-09-12.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-09-13.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-09-15.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-09-18.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-09-25.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-09-29.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-10-03.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-10-05.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-11-03.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-11-08.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-11-16.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-12-21.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2023-12-29.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2024-01-02-01.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2024-01-08.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2024-01-23 (2).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2024-01-23.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2024-01-24.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2024-01-25.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2024-02-05.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2024-02-07.txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2024-03-11 (2).txt
# C:/Users/sakhi/Desktop/NLP/results/judgement2024-03-13.txt
